# %% [markdown]
# <a href="https://colab.research.google.com/github/brishti-c/scratchpad/blob/main/nb_2026_01_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/brishti-c/scratchpad
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 27 (delta 2), reused 1 (delta 1), pack-reused 23 (from 1)
# Receiving objects: 100% (27/27), 28.82 KiB | 7.20 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
import urllib.request
import os
import zipfile
import os

def download_data(force=False):
    """Download and extract course data from Zenodo."""

    zip_path = 'data.zip'
    data_dir = './data'

    if not os.path.exists(zip_path) or force:
        print("Downloading course data...")
        urllib.request.urlretrieve(
            'https://zenodo.org/records/18235955/files/data.zip?download=1',
            zip_path
        )
        print("Download complete")

    if not os.path.exists(data_dir) or force:
        print("Extracting data files...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(data_dir)
        print("Data extracted")

    return data_dir


if __name__ == "__main__":
    download_data()
# Out:
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import pandas as pd
df = pd.read_csv('/content/data/zoo.csv', encoding = 'latin1')
df.head()
# Out:
#      animal  hair  feathers  eggs  milk  airborne  aquatic  predator  toothed  \
# 0  aardvark     1         0     0     1         0        0         1        1
# 1  antelope     1         0     0     1         0        0         0        1
# 2      bass     0         0     1     0         0        1         1        1
# 3      bear     1         0     0     1         0        0         1        1
# 4      boar     1         0     0     1         0        0         1        1
#
#    backbone  breathes  venomous  fins  legs  tail  domestic  catsize  class
# 0         1         1         0     0     4     0         0        1      1
# 1         1         1         0     0     4     1         0        1      1
# 2         1         0         0     1     0     1         0        0      4
# 3         1         1         0     0     4     0         0        1      1
# 4         1         1         0     0     4     1         0        1      1

# %%
df.shape
# Out:
# (101, 18)

# %%
df.columns
# Out:
# Index(['animal', 'hair', 'feathers', 'eggs', 'milk', 'airborne', 'aquatic',
#        'predator', 'toothed', 'backbone', 'breathes', 'venomous', 'fins',
#        'legs', 'tail', 'domestic', 'catsize', 'class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# animal      object
# hair         int64
# feathers     int64
# eggs         int64
# milk         int64
# airborne     int64
# aquatic      int64
# predator     int64
# toothed      int64
# backbone     int64
# breathes     int64
# venomous     int64
# fins         int64
# legs         int64
# tail         int64
# domestic     int64
# catsize      int64
# class        int64
# dtype: object

# %%
df['animal'].unique()
# Out:
# array(['aardvark', 'antelope', 'bass', 'bear', 'boar', 'buffalo', 'calf',
#        'carp', 'catfish', 'cavy', 'cheetah', 'chicken', 'chub', 'clam',
#        'crab', 'crayfish', 'crow', 'deer', 'dogfish', 'dolphin', 'dove',
#        'duck', 'elephant', 'flamingo', 'flea', 'frog', 'fruitbat',
#        'giraffe', 'girl', 'gnat', 'goat', 'gorilla', 'gull', 'haddock',
#        'hamster', 'hare', 'hawk', 'herring', 'honeybee', 'housefly',
#        'kiwi', 'ladybird', 'lark', 'leopard', 'lion', 'lobster', 'lynx',
#        'mink', 'mole', 'mongoose', 'moth', 'newt', 'octopus', 'opossum',
#        'oryx', 'ostrich', 'parakeet', 'penguin', 'pheasant', 'pike',
#        'piranha', 'pitviper', 'platypus', 'polecat', 'pony', 'porpoise',
#        'puma', 'pussycat', 'raccoon', 'reindeer', 'rhea', 'scorpion',
#        'seahorse', 'seal', 'sealion', 'seasnake', 'seawasp', 'skimmer',
#        'skua', 'slowworm', 'slug', 'sole', 'sparrow', 'squirrel',
# ...

# %%
df['predator'].value_counts()
# Out:
# predator
# 1    56
# 0    45
# Name: count, dtype: int64

# %%
df['predator'].hist()
# Out:
# <Axes: >

# %%
df['class'].value_counts()
# Out:
# class
# 1    41
# 2    20
# 4    13
# 7    10
# 6     8
# 3     5
# 5     4
# Name: count, dtype: int64

# %%
df['class'].hist()
# Out:
# <Axes: >
